# %%
import re
import pandas as pd

from fuzzywuzzy import fuzz


from collections import defaultdict

# %%
f1 = 'D:\\projects\\_external_files\\cod_files\\afg_adminboundaries_tabulardata.xlsx'
f2 = 'D:\\projects\\_external_files\\cod_files\\ukr_adminboundaries_tabulardata.xlsx'
f3 = 'D:\\projects\\_external_files\\cod_files\\tur_adminboundaries_tabulardata.xlsx'
f4 = 'D:\\projects\\_external_files\\cod_files\\syr_adminboundaries_tabulardata.xlsx'

files = [f1, f2, f3, f4]

# %%
def get_all_cols_for_level(df, lvl=0):

    return_df = pd.DataFrame(columns=['pcode','adm','location_name','adm_lvl'])
    #lvl_patterns={}

    while lvl >= 0:
        column_levels = [c for c in df.columns if str(lvl) in c]
        if len(column_levels) == 0:
            lvl -= 1
            continue

        
        pcodes = []
        names = []
        others = []
    
        for col in column_levels:
            print(col)
            pcode_match = re.match(r'(adm)(\d+)_pcode', col.lower())
            name_match = re.match(r'(adm)(\d+)_([a-z]{2,3})', col.lower())
            alt_match = re.match(r'(adm)(\d+)(alt)(\d+)_([a-z]{2,3})', col.lower())
            if pcode_match:
                pcodes.append(pcode_match.group(0))
            elif name_match:
                names.append(name_match.group(0))
            elif alt_match:
                #throw away alts for now
                pass
            else:
                others.append(col)
    
        #sanity checks
        if len(pcodes) != 1:
            print(f"unexpected condition - pcodes len should be 1. {pcodes}")
            print(pcodes)
        if len(names) < 1:
            print(f"unexpected condition - names len should be at least 1. {names}")
        if len(others) > 0:
            print(f"unexpected condition, but not fatal - others len should be empty. {others}")

    
        required_columns = names
        required_columns.extend(pcodes)
        
    
        # Melting the DataFrame to combine columns into rows
        melted_df = df[required_columns].melt(id_vars=pcodes[0], var_name='adm', value_name='location_name').copy()
        melted_df['adm_lvl'] = lvl
        melted_df = melted_df.rename(columns={pcodes[0]:'pcode'})


        return_df = pd.concat([return_df, melted_df])

        lvl -= 1

    #print(lvl_patterns)
    return_df['pcode_prefix'] = return_df['pcode'].apply(lambda x: x[0:2])
    
    return_df['lang_code'] = return_df['adm'].apply(lambda x: x.split('_')[1])
    country=''
    country = return_df['location_name'][(return_df['adm_lvl'] == 0) & (return_df['lang_code'] == 'en')].tolist()[0]
    return_df['country'] = country
    return_df = return_df.drop_duplicates().reset_index()
    return_df = return_df[return_df['location_name'].isna() == False]

    #remove common variations in names that can cause misses
    return_df['location_normalized'] = return_df['location_name'].str.lower()
    return_df['location_normalized'] = return_df['location_normalized'].apply(lambda x:  re.sub(r'[^a-zA-Z]', '', x))
                                                                              
                                                

    
    return return_df[['country','pcode_prefix','location_name','location_normalized','pcode','adm_lvl','lang_code']]

# %%
def standardize_column_names(df, case='lower'):
    cols = df.columns
    new_columns={}
    if case == 'lower':
        for c in cols:
            new_columns[c] = c.lower()
    elif case == 'upper':
        for c in cols:
            new_columns[c] = c.upper()

    return df.rename(columns=new_columns)

# %%
def process_cods(f):
    preferred_level = 'ADM3'
    backup_level = 'ADM2'

    # Create an ExcelFile object
    xls = pd.ExcelFile(f)
    sheet_names = xls.sheet_names

    if preferred_level in sheet_names:
        df = pd.read_excel(xls, sheet_name=preferred_level)
    else:
        df = pd.read_excel(xls, sheet_name=backup_level)

    return df

# %%
df_location = pd.DataFrame(columns=['country','pcode_prefix','location_name','pcode','adm_lvl','lang_code'])
for f in files:
    print(f)

    #try to access the ADM3 tab and load to a df
    df = process_cods(f)
    df = standardize_column_names(df)
    df_new_loc = get_all_cols_for_level(df, lvl=4)


    df_location = pd.concat([df_location, df_new_loc])


    print(df_location.shape)

df_location
# Out:
# D:\projects\_external_files\cod_files\afg_adminboundaries_tabulardata.xlsx
# adm2_en
# adm2_da
# adm2_pcode
# adm2_ref
# adm2alt1_en
# adm2alt2_en
# adm2alt1_da
# adm2alt2_da
# adm2alt1_en
# adm2alt1_da
# adm1_en
# adm1_da
# adm1_pcode
# adm0_en
# adm0_da
# adm0_pcode
# (872, 7)
# D:\projects\_external_files\cod_files\ukr_adminboundaries_tabulardata.xlsx
# adm3_en
# adm3_ua
# adm3_ru
# adm3_pcode
# adm3_ref
# adm3alt1_en
# adm3alt2_en
# adm3alt1_ua
# adm3alt2_ua
# adm3alt1_ru
# adm3alt2_ru
# adm3alt2_en
# adm3alt2_ua
# adm3alt2_ru
# adm2_en
# adm2_ua
# adm2_ru
# adm2_pcode
# adm3alt1_en
# adm3alt1_ua
# adm3alt1_ru
# adm1_en
# adm1_ua
# adm1_ru
# adm1_pcode
# adm0_en
# adm0_ua
# adm0_ru
# adm0_pcode
# (6680, 7)
# D:\projects\_external_files\cod_files\tur_adminboundaries_tabulardata.xlsx
# adm2_tr
# adm2_en
# adm2_pcode
# adm1_tr
# adm1_en
# adm1_pcode
# adm0_tr
# adm0_en
# adm0_pcode
# (8790, 7)
# D:\projects\_external_files\cod_files\syr_adminboundaries_tabulardata.xlsx
# adm3_en
# adm3_ar
# adm3_pcode
# admin3refname_en
# unexpected condition, but not fatal - others len should be empty. ['admin3refname_en']
# adm2_en
# adm2_ar
# adm2_pcode
# adm1_en
# adm1_ar
# adm1_pcode
# adm0_en
# adm0_ar
# adm0_pcode
# (9488, 7)
#                   country pcode_prefix              location_name   pcode  \
# 0             Afghanistan           AF                      Khash  AF1705
# 1             Afghanistan           AF            Hazrat-e-Sultan  AF2002
# 2             Afghanistan           AF                 Pul-e-Alam  AF0501
# 3             Afghanistan           AF                  Mata Khan  AF1202
# 4             Afghanistan           AF                   Gosfandi  AF2206
# ..                    ...          ...                        ...     ...
# 693  Syrian Arab Republic           SY                   ريف دمشق    SY03
# 694  Syrian Arab Republic           SY                      طرطوس    SY10
# 695  Syrian Arab Republic           SY                       دمشق    SY01
# 696  Syrian Arab Republic           SY       Syrian Arab Republic      SY
# 697  Syrian Arab Republic           SY  الجمهورية العربية السورية      SY
#
#     adm_lvl lang_code location_normalized
# 0         2        en               khash
# 1         2        en       hazratesultan
# 2         2        en            pulealam
# 3         2        en            matakhan
# 4         2        en            gosfandi
# ..      ...       ...                 ...
# 693       1        ar
# 694       1        ar
# 695       1        ar
# 696       0        en  syrianarabrepublic
# 697       0        ar
#
# [9488 rows x 7 columns]

# %%
df_location['lvl_pcode_len'] = df_location['pcode'].apply(lambda x:len(x))
df_pcode_struct = df_location[['pcode_prefix','adm_lvl','lvl_pcode_len']].copy().drop_duplicates().reset_index(drop=True)
pivot_df = df_pcode_struct.pivot(index='pcode_prefix', columns='adm_lvl', values='lvl_pcode_len')
segment_total_len = [int(i) for i in pivot_df.loc['AF'].tolist() if i>0]
segment_total_len

def split_pcode_struct(row):
    lvl=row['adm_lvl']
    pcode=row['pcode']
    c_code = row['pcode_prefix']
    segment_total_len = [int(i) for i in pivot_df.loc[c_code].tolist() if i>0]
    pcode_list = pcode.split()
    last_i=0
    newpcode=''
    for i in segment_total_len:
        x = pcode[last_i:i] 
        last_i = i
        if i <= len(pcode): #make sure the segment length doesn't exceed the length of the pcode
            newpcode = newpcode + x + '.'

    return newpcode[0:-1]

df_location['split_pcode'] = df_location.apply(split_pcode_struct, axis=1)
df_location
# Out:
#                   country pcode_prefix              location_name   pcode  \
# 0             Afghanistan           AF                      Khash  AF1705
# 1             Afghanistan           AF            Hazrat-e-Sultan  AF2002
# 2             Afghanistan           AF                 Pul-e-Alam  AF0501
# 3             Afghanistan           AF                  Mata Khan  AF1202
# 4             Afghanistan           AF                   Gosfandi  AF2206
# ..                    ...          ...                        ...     ...
# 693  Syrian Arab Republic           SY                   ريف دمشق    SY03
# 694  Syrian Arab Republic           SY                      طرطوس    SY10
# 695  Syrian Arab Republic           SY                       دمشق    SY01
# 696  Syrian Arab Republic           SY       Syrian Arab Republic      SY
# 697  Syrian Arab Republic           SY  الجمهورية العربية السورية      SY
#
#     adm_lvl lang_code location_normalized  lvl_pcode_len split_pcode
# 0         2        en               khash              6    AF.17.05
# 1         2        en       hazratesultan              6    AF.20.02
# 2         2        en            pulealam              6    AF.05.01
# 3         2        en            matakhan              6    AF.12.02
# 4         2        en            gosfandi              6    AF.22.06
# ..      ...       ...                 ...            ...         ...
# 693       1        ar                                  4       SY.03
# 694       1        ar                                  4       SY.10
# 695       1        ar                                  4       SY.01
# 696       0        en  syrianarabrepublic              2          SY
# 697       0        ar                                  2          SY
#
# [9488 rows x 9 columns]

# %%
df_location.to_csv("c://temp//locations.csv", encoding='utf-8-sig', index=False)
df_location.to_csv("D://projects//_external_files//cod_files//combined_locations//locations.csv", encoding='utf-8-sig', index=False)

# %% [markdown]
# # Now use the DF

# %%
def get_pcode_from_location(loc, country_prefix='XX'):

    if country_prefix != 'XX': #if the country prefix is set, limit search to that
        df_loc = df_location[df_location['pcode_prefix']]
    else:
        df_loc = df_location
        
    matches = df_loc['pcode'][df_loc['location_name'].str.lower() == loc.lower()].tolist()
    matches = list(set(matches))

    #if the match fails, try again on the normalized name
    if len(matches) == 0:
        #remove common variations in names that can cause misses
        n_loc = re.sub(r'[^a-zA-Z]', '', loc)

        #this will cause problems for non-English.. so if then len is 0, exit
        if len(n_loc) == 0:
            return []
            
        matches = df_loc['pcode'][df_loc['location_normalized'].str.lower() == n_loc.lower()].tolist()

        
        

    #now check results
    if len(matches) > 1:
        print(f"more than 1 matches... likely due to different granularity of entities with the same name (ie. Herat City in Herat Province) {matches}")
        return matches
    elif len(matches) == 1:
        return matches

    else:
        #couldn't find a match, do a fuzzy search
        compare_list = list(set(df_loc['location_name'].tolist()))
        possible_matches=[]
        for i in compare_list:
            if fuzz.ratio(loc,i) > 70:
                possible_matches.append(i)
                return [f"No exact match to '{loc}'. see if these alternative spellings are correct: {possible_matches}"]

    
    return []
                
        

#different scripts
script_check = ['Sharak-e-Hayratan','حضرت سلطان','Кальчикская','Tekirdagi','homs']
for r in script_check:
    res = get_pcode_from_location(r)
    print(f"searched for {r:<20} ->   {res}")

print()

#afghan references
afg_refs = ['Aliabad','Injil','Gulran','zindajan','kohsan'
            ,'Shakiban','Nazir Abad','Sanjab'
            ,'nazir','Ghar Moshak','Botan'
           ,'Hirat']
for r in afg_refs:
    res = get_pcode_from_location(r)
    print(f"searched for {r:20} : -> {res}")
# Out:
# searched for Sharak-e-Hayratan    ->   ['AF2116']
# searched for حضرت سلطان           ->   ['AF2002']
# searched for Кальчикская          ->   ['UA1414001']
# searched for Tekirdagi            ->   []
# more than 1 matches... likely due to different granularity of entities with the same name (ie. Herat City in Herat Province) ['SY04', 'SY040100', 'SY0401']
# searched for homs                 ->   ['SY04', 'SY040100', 'SY0401']
#
# searched for Aliabad              : -> ['AF1903']
# searched for Injil                : -> ['AF3202']
# searched for Gulran               : -> ['AF3208']
# searched for zindajan             : -> ['AF3205']
# searched for kohsan               : -> ['AF3213']
# searched for Shakiban             : -> ["No exact match to 'Shakiban'. see if these alternative spellings are correct: ['Thiban']"]
# searched for Nazir Abad           : -> ["No exact match to 'Nazir Abad'. see if these alternative spellings are correct: ['Ghazi Abad']"]
# searched for Sanjab               : -> ["No exact match to 'Sanjab'. see if these alternative spellings are correct: ['Panjab']"]
# searched for nazir                : -> []
# searched for Ghar Moshak          : -> []
# searched for Botan                : -> []
# more than 1 matches... likely due to different granularity of entities with the same name (ie. Herat City in Herat Province) ['AF32', 'AF3201']
# searched for Hirat                : -> ['AF32', 'AF3201']

# %%
df_location
# Out:
#                   country pcode_prefix              location_name   pcode  \
# 0             Afghanistan           AF                      Khash  AF1705
# 1             Afghanistan           AF            Hazrat-e-Sultan  AF2002
# 2             Afghanistan           AF                 Pul-e-Alam  AF0501
# 3             Afghanistan           AF                  Mata Khan  AF1202
# 4             Afghanistan           AF                   Gosfandi  AF2206
# ..                    ...          ...                        ...     ...
# 693  Syrian Arab Republic           SY                   ريف دمشق    SY03
# 694  Syrian Arab Republic           SY                      طرطوس    SY10
# 695  Syrian Arab Republic           SY                       دمشق    SY01
# 696  Syrian Arab Republic           SY       Syrian Arab Republic      SY
# 697  Syrian Arab Republic           SY  الجمهورية العربية السورية      SY
#
#     adm_lvl lang_code location_normalized  lvl_pcode_len split_pcode
# 0         2        en               khash              6    AF.17.05
# 1         2        en       hazratesultan              6    AF.20.02
# 2         2        en            pulealam              6    AF.05.01
# 3         2        en            matakhan              6    AF.12.02
# 4         2        en            gosfandi              6    AF.22.06
# ..      ...       ...                 ...            ...         ...
# 693       1        ar                                  4       SY.03
# 694       1        ar                                  4       SY.10
# 695       1        ar                                  4       SY.01
# 696       0        en  syrianarabrepublic              2          SY
# 697       0        ar                                  2          SY
#
# [9488 rows x 9 columns]

# %%
def get_adm_lvl_from_pcode(pcode):
    return list(set(df_location['adm_lvl'][df_location['pcode'] == pcode].tolist()))

print(get_adm_lvl_from_pcode('TUR033'))
# Out:
# [1]

# %%
def get_name_in_lang(pcode, lang='en'):
    return list(set(df_location['location_name'][(df_location['pcode'] == pcode) & (df_location['lang_code'] == lang)].tolist()))

print(get_name_in_lang('UA1414001', 'en'))
print(get_name_in_lang('UA1414001', 'ru'))
print(get_name_in_lang('UA1414001', 'ua'))
print(get_name_in_lang('UA85', 'en'))
# Out:
# ['Kalchytska']
# ['Кальчикская']
# ['Кальчицька']
# ['Sevastopol']

# %%
locations = ['Adana', 'Osmaniye', 'Hatay', 'Kilis', 'Gaziantep', 'Sanliurfa', 'Adiyaman', 'Kahramanmaras', 'Malatya', 'Elazig', 'Diyarbakir']
for l in locations:
    print(f"{l} -- {get_pcode_from_location(l)}")
    print()
# Out:
# Adana -- ['TUR001']
#
# more than 1 matches... likely due to different granularity of entities with the same name (ie. Herat City in Herat Province) ['TUR080', 'TUR080005']
# Osmaniye -- ['TUR080', 'TUR080005']
#
# Hatay -- ['TUR031']
#
# more than 1 matches... likely due to different granularity of entities with the same name (ie. Herat City in Herat Province) ['TUR079', 'TUR079002']
# Kilis -- ['TUR079', 'TUR079002']
#
# Gaziantep -- ['TUR027']
#
# Sanliurfa -- ['TUR063']
#
# more than 1 matches... likely due to different granularity of entities with the same name (ie. Herat City in Herat Province) ['TUR002001', 'TUR002']
# Adiyaman -- ['TUR002001', 'TUR002']
#
# Kahramanmaras -- ['TUR046']
#
# Malatya -- ['TUR044']
#
# more than 1 matches... likely due to different granularity of entities with the same name (ie. Herat City in Herat Province) ['TUR023005', 'TUR023']
# Elazig -- ['TUR023005', 'TUR023']
#
# Diyarbakir -- ['TUR021']

# %%
#get descendents of 
def get_descendents_of(pcode, lang='en', include_self=True):
    if include_self==True:
        return df_location[df_location['pcode'].str.contains(pcode) & (df_location['lang_code'] == lang)]
    else:
        return df_location[df_location['pcode'].str.contains(pcode) & (df_location['lang_code'] == lang)\
        & (df_location['pcode'] != pcode)]

        
get_descendents_of('TUR001', include_self=False)
# Out:
#     country pcode_prefix location_name      pcode adm_lvl lang_code  \
# 973  TURKEY           TU        ALADAG  TUR001001       2        en
# 974  TURKEY           TU        CEYHAN  TUR001002       2        en
# 975  TURKEY           TU      CUKUROVA  TUR001003       2        en
# 976  TURKEY           TU          FEKE  TUR001004       2        en
# 977  TURKEY           TU      IMAMOGLU  TUR001005       2        en
# 978  TURKEY           TU     KARAISALI  TUR001006       2        en
# 979  TURKEY           TU       KARATAS  TUR001007       2        en
# 980  TURKEY           TU         KOZAN  TUR001008       2        en
# 981  TURKEY           TU       POZANTI  TUR001009       2        en
# 982  TURKEY           TU     SAIMBEYLI  TUR001010       2        en
# 983  TURKEY           TU       SARICAM  TUR001011       2        en
# 984  TURKEY           TU        SEYHAN  TUR001012       2        en
# 985  TURKEY           TU    TUFANBEYLI  TUR001013       2        en
# 986  TURKEY           TU    YUMURTALIK  TUR001014       2        en
# 987  TURKEY           TU       YUREGIR  TUR001015       2        en
#
#     location_normalized  lvl_pcode_len  split_pcode
# 973              aladag              9  TUR.001.001
# 974              ceyhan              9  TUR.001.002
# 975            cukurova              9  TUR.001.003
# 976                feke              9  TUR.001.004
# 977            imamoglu              9  TUR.001.005
# 978           karaisali              9  TUR.001.006
# 979             karatas              9  TUR.001.007
# 980               kozan              9  TUR.001.008
# 981             pozanti              9  TUR.001.009
# 982           saimbeyli              9  TUR.001.010
# 983             saricam              9  TUR.001.011
# 984              seyhan              9  TUR.001.012
# 985          tufanbeyli              9  TUR.001.013
# 986          yumurtalik              9  TUR.001.014
# 987             yuregir              9  TUR.001.015

# %%
def get_admin_chain(pcode, lang='en'):
    split_pcode = df_location['split_pcode'][df_location['pcode'] == pcode].tolist()[0]
    levels = split_pcode.split(".")
    pc =''
    admin_chain = []
    #rebuild the pcode one level at a time
    for i in levels:
        pc = pc + i
        admin_chain.append(df_location['location_name'][(df_location['pcode'] == pc) & (df_location['lang_code'] == lang)].tolist()[0])

    return admin_chain
#UA1414001
get_admin_chain('UA0102013', 'en')
# Out:
# ['Ukraine', 'Autonomous Republic of Crimea', 'Bakhchysaraiskyi', 'Holubynska']

# %%
search_loc = 'Kalchytska'
get_admin_chain('UA0102011')
# Out:
# ['Ukraine', 'Autonomous Republic of Crimea', 'Bakhchysaraiskyi', 'Vilinska']

# %%
get_descendents_of('UA0116', include_self=False)
# Out:
#      country pcode_prefix   location_name      pcode adm_lvl lang_code  \
# 217  Ukraine           UA      Hvardiiska  UA0116001       3        en
# 218  Ukraine           UA       Hresivska  UA0116003       3        en
# 219  Ukraine           UA       Dobrivska  UA0116005       3        en
# 220  Ukraine           UA          Donska  UA0116007       3        en
# 221  Ukraine           UA    Zhuravlivska  UA0116009       3        en
# 222  Ukraine           UA    Kolchuhynska  UA0116011       3        en
# 223  Ukraine           UA        Mazanska  UA0116013       3        en
# 224  Ukraine           UA     Mykolaivska  UA0116015       3        en
# 225  Ukraine           UA       Myrnivska  UA0116017       3        en
# 226  Ukraine           UA  Molodizhnenska  UA0116019       3        en
# 227  Ukraine           UA  Novoandriivska  UA0116021       3        en
# 228  Ukraine           UA    Novoselivska  UA0116023       3        en
# 229  Ukraine           UA     Pervomaiska  UA0116025       3        en
# 230  Ukraine           UA        Perovska  UA0116027       3        en
# 231  Ukraine           UA       Pozharska  UA0116029       3        en
# 232  Ukraine           UA     Rodnykivska  UA0116031       3        en
# 233  Ukraine           UA   Simferopolska  UA0116033       3        en
# 234  Ukraine           UA    Skvortsivska  UA0116035       3        en
# 235  Ukraine           UA       Trudivska  UA0116037       3        en
# 236  Ukraine           UA     Ukromnivska  UA0116039       3        en
# 237  Ukraine           UA   Urozhainivska  UA0116041       3        en
# 238  Ukraine           UA      Chystenska  UA0116043       3        en
# 239  Ukraine           UA     Shyrokivska  UA0116045       3        en
# 240  Ukraine           UA     Shkilnenska  UA0116047       3        en
#
#     location_normalized  lvl_pcode_len   split_pcode
# 217          hvardiiska              9  UA.01.16.001
# 218           hresivska              9  UA.01.16.003
# 219           dobrivska              9  UA.01.16.005
# 220              donska              9  UA.01.16.007
# 221        zhuravlivska              9  UA.01.16.009
# 222        kolchuhynska              9  UA.01.16.011
# 223            mazanska              9  UA.01.16.013
# 224         mykolaivska              9  UA.01.16.015
# 225           myrnivska              9  UA.01.16.017
# 226      molodizhnenska              9  UA.01.16.019
# 227      novoandriivska              9  UA.01.16.021
# 228        novoselivska              9  UA.01.16.023
# 229         pervomaiska              9  UA.01.16.025
# 230            perovska              9  UA.01.16.027
# 231           pozharska              9  UA.01.16.029
# 232         rodnykivska              9  UA.01.16.031
# 233       simferopolska              9  UA.01.16.033
# 234        skvortsivska              9  UA.01.16.035
# 235           trudivska              9  UA.01.16.037
# 236         ukromnivska              9  UA.01.16.039
# 237       urozhainivska              9  UA.01.16.041
# 238          chystenska              9  UA.01.16.043
# 239         shyrokivska              9  UA.01.16.045
# 240         shkilnenska              9  UA.01.16.047

# %%
#test loading assertions

df_assertions = pd.read_excel("D:\\projects\\_external_files\\surveyor\\assertions.xlsx")
df_assertions
# Out:
#        pcode       attribute  numeric_value date_of_observation date_of_event  \
# 0  UA0102005  bicycle_bought             50          2023-11-18    2023-11-10
# 1  UA0116021  bicycle_bought            500          2023-11-18    2023-11-10
# 2       UA01  bicycle_bought          15000          2023-11-19    2023-11-10
#
#                source_sentence
# 0                blah blah bla
# 1                blah blah bla
# 2  a different source sentence

# %%
df_joined = df_location.merge(df_assertions, left_on='pcode', right_on='pcode')
df_joined[df_joined['lang_code'] == 'en']
# Out:
#    country pcode_prefix                  location_name      pcode adm_lvl  \
# 0  Ukraine           UA                Bakhchysaraiska  UA0102005       3
# 3  Ukraine           UA                 Novoandriivska  UA0116021       3
# 6  Ukraine           UA  Autonomous Republic of Crimea       UA01       1
#
#   lang_code         location_normalized  lvl_pcode_len   split_pcode  \
# 0        en             bakhchysaraiska              9  UA.01.02.005
# 3        en              novoandriivska              9  UA.01.16.021
# 6        en  autonomousrepublicofcrimea              4         UA.01
#
#         attribute  numeric_value date_of_observation date_of_event  \
# 0  bicycle_bought             50          2023-11-18    2023-11-10
# 3  bicycle_bought            500          2023-11-18    2023-11-10
# 6  bicycle_bought          15000          2023-11-19    2023-11-10
#
#                source_sentence
# 0                blah blah bla
# 3                blah blah bla
# 6  a different source sentence

# %% [markdown]
# ## END

# %%
dfx = df.set_index(['adm0_pcode','adm1_pcode','adm2_pcode','adm3_pcode'])
dfx
# Out:
#                                                           adm0_en  \
# adm0_pcode adm1_pcode adm2_pcode adm3_pcode
# SY         SY07       SY0705     SY070500    Syrian Arab Republic
#                                  SY070501    Syrian Arab Republic
#                                  SY070502    Syrian Arab Republic
#                       SY0704     SY070400    Syrian Arab Republic
#                                  SY070401    Syrian Arab Republic
# ...                                                           ...
#            SY03       SY0309     SY030900    Syrian Arab Republic
#                                  SY030902    Syrian Arab Republic
#            SY01       SY0100     SY010000    Syrian Arab Republic
#            SY03       SY0301     SY030102    Syrian Arab Republic
#                                  SY030107    Syrian Arab Republic
#
#                                                                adm0_ar  \
# adm0_pcode adm1_pcode adm2_pcode adm3_pcode
# SY         SY07       SY0705     SY070500    الجمهورية العربية السورية
#                                  SY070501    الجمهورية العربية السورية
#                                  SY070502    الجمهورية العربية السورية
#                       SY0704     SY070400    الجمهورية العربية السورية
#                                  SY070401    الجمهورية العربية السورية
# ...                                                                ...
#            SY03       SY0309     SY030900    الجمهورية العربية السورية
#                                  SY030902    الجمهورية العربية السورية
#            SY01       SY0100     SY010000    الجمهورية العربية السورية
#            SY03       SY0301     SY030102    الجمهورية العربية السورية
#                                  SY030107    الجمهورية العربية السورية
#
#                                                     adm1_en   adm1_ar  \
# adm0_pcode adm1_pcode adm2_pcode adm3_pcode
# SY         SY07       SY0705     SY070500             Idleb      إدلب
#                                  SY070501             Idleb      إدلب
#                                  SY070502             Idleb      إدلب
#                       SY0704     SY070400             Idleb      إدلب
#                                  SY070401             Idleb      إدلب
# ...                                                     ...       ...
#            SY03       SY0309     SY030900    Rural Damascus  ريف دمشق
#                                  SY030902    Rural Damascus  ريف دمشق
#            SY01       SY0100     SY010000          Damascus      دمشق
#            SY03       SY0301     SY030102    Rural Damascus  ريف دمشق
#                                  SY030107    Rural Damascus  ريف دمشق
#
#                                                      adm2_en        adm2_ar  \
# adm0_pcode adm1_pcode adm2_pcode adm3_pcode
# SY         SY07       SY0705     SY070500              Ariha          أريحا
#                                  SY070501              Ariha          أريحا
#                                  SY070502              Ariha          أريحا
#                       SY0704     SY070400    Jisr-Ash-Shugur     جسر الشغور
#                                  SY070401    Jisr-Ash-Shugur     جسر الشغور
# ...                                                      ...            ...
#            SY03       SY0309     SY030900            Darayya          داريا
#                                  SY030902            Darayya          داريا
#            SY01       SY0100     SY010000           Damascus           دمشق
#            SY03       SY0301     SY030102     Rural Damascus  مركز ريف دمشق
#                                  SY030107     Rural Damascus  مركز ريف دمشق
#
#                                                      adm3_en          adm3_ar  \
# adm0_pcode adm1_pcode adm2_pcode adm3_pcode
# SY         SY07       SY0705     SY070500              Ariha       مركز أريحا
#                                  SY070501              Ehsem             احسم
#                                  SY070502            Mhambal            محمبل
#                       SY0704     SY070400    Jisr-Ash-Shugur  مركز جسر الشغور
#                                  SY070401             Badama            بداما
# ...                                                      ...              ...
#            SY03       SY0309     SY030900     Markaz Darayya       مركز داريا
#                                  SY030902        Hajar Aswad     الحجر الأسود
#            SY01       SY0100     SY010000           Damascus             دمشق
#            SY03       SY0301     SY030102            Babella            ببيلا
#                                  SY030107            Qudsiya            قدسيا
#
#                                             admin3refname_en lastupdatedate  \
# adm0_pcode adm1_pcode adm2_pcode adm3_pcode
# SY         SY07       SY0705     SY070500              Ariha     2016-09-05
#                                  SY070501              Ehsem     2016-09-05
#                                  SY070502            Mhambal     2016-09-05
#                       SY0704     SY070400    Jisr-Ash-Shugur     2016-09-05
#                                  SY070401             Badama     2016-09-05
# ...                                                      ...            ...
#            SY03       SY0309     SY030900     Markaz Darayya     2016-09-05
#                                  SY030902        Hajar Aswad     2016-09-05
#            SY01       SY0100     SY010000           Damascus     2016-09-05
#            SY03       SY0301     SY030102            Babella     2016-09-05
#                                  SY030107            Qudsiya     2016-09-05
#
#                                                 validon  validto
# adm0_pcode adm1_pcode adm2_pcode adm3_pcode
# SY         SY07       SY0705     SY070500    2016-09-05      NaN
#                                  SY070501    2016-09-05      NaN
#                                  SY070502    2016-09-05      NaN
#                       SY0704     SY070400    2016-09-05      NaN
#                                  SY070401    2016-09-05      NaN
# ...                                                 ...      ...
#            SY03       SY0309     SY030900    2016-09-05      NaN
#                                  SY030902    2016-09-05      NaN
#            SY01       SY0100     SY010000    2016-09-05      NaN
#            SY03       SY0301     SY030102    2016-09-05      NaN
#                                  SY030107    2016-09-05      NaN
#
# [272 rows x 12 columns]

# %%
dfx_nm = df.set_index(['adm0_en','adm1_en','adm2_en','adm3_en'])
dfx_nm = dfx_nm.sort_index()
dfx_nm['num_dead'] = 10
#dfx_nm.loc[('Ukraine','Autonomous Republic of Crimea','Bakhchysaraiskyi','Aromatnenska')]['num_dead'] = 20
#dfx_nm.loc[('Ukraine','Autonomous Republic of Crimea','Bakhchysaraiskyi')][['num_dead']] = 200

# %%
dfx_nm[['num_dead']] #.loc[('Ukraine','Autonomous Republic of Crimea','Bakhchysaraiskyi')]
# Out:
#                                                                       num_dead
# adm0_en              adm1_en    adm2_en    adm3_en
# Syrian Arab Republic Al-Hasakeh Al-Hasakeh Al-Hasakeh                       10
#                                            Areesheh                         10
#                                            Be'r Al-Hulo Al-Wardeyyeh        10
#                                            Hole                             10
#                                            Markada                          10
# ...                                                                        ...
#                      Tartous    Tartous    Kareemeh                         10
#                                            Kherbet Elma'aza                 10
#                                            Safsafa                          10
#                                            Soda Khawabi                     10
#                                            Tartous                          10
#
# [272 rows x 1 columns]

# %%
dfx_nm['Ukraine']['Autonomous Republic of Crimea']['Bakhchysaraiskyi']['Aromatnenska']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File D:\projects\virtual_environments\topic_surveyor\Lib\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Ukraine'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 dfx_nm['Ukraine']['Autonomous Republic of Crimea']['Bakhchysaraiskyi']['Aromatnenska']
#
# File D:\projects\virtual_environments\topic_surveyor\Lib\site-packages\pandas\core\frame.py:3896, in DataFrame.__getitem__(self, key)
#    3894 if self.columns.nlevels > 1:
#    3895     return self._getitem_multilevel(key)
# -> 3896 indexer = self.columns.get_loc(key)
#    3897 if is_integer(indexer):
#    3898     indexer = [indexer]
#
# File D:\projects\virtual_environments\topic_surveyor\Lib\site-packages\pandas\core\indexes\base.py:3797, in Index.get_loc(self, key)
#    3792     if isinstance(casted_key, slice) or (
#    3793         isinstance(casted_key, abc.Iterable)
#    3794         and any(isinstance(x, slice) for x in casted_key)
#    3795     ):
#    3796         raise InvalidIndexError(key)
# -> 3797     raise KeyError(key) from err
#    3798 except TypeError:
#    3799     # If we have a listlike key, _check_indexing_error will raise
#    3800     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3801     #  the TypeError.
#    3802     self._check_indexing_error(key)
#
# KeyError: 'Ukraine'

# %%
for i in dfx.index:
    print(i)

# %%
x = ['Hama', 'Harim', 'Idleb', 'Afrin', 'Aleppo', 'Kahramanmara', 'Malatya', 'Hatay', 'Syria', 'Adana', 'Gaziantep', 'Sanliurfa', 'Zonguldak', 'Ordu', 'Adiyaman', 'Sinop', 'ENAR(httpsreliefweb', 'Lattakia', 'Bingl', 'Kayseri', 'Mardin', 'Tunceli', 'Batman', 'Turkey', 'Samsun', 'Amasya', 'Jandairis', 'intsitesdefaultfilesstylessmallpublicpreviews75d275d203f6e46e4f6d8ade8c77a85cb739', 'Kastamonu', 'Homs', 'afadTasarimafadlogoen', 'Tartous', 'intnode3976432', 'intnode3934516', 'Provinces of', 'intnode3941882', 'Mersin', 'intnode3963175', 'intnode3938340', 'Sakarya', 'Bolu', 'Bartin', 'Karabk', 'Giresun', 'intnode3969031', 'intnode3944550', 'Naqaa']

for l in x:
    r = get_pcode_from_location(l)

    if len(r) > 0:
        if r[0][:2] == 'TU':
            country = 'Turkiye'
        elif r[0][:2] == 'SY':
            country = 'Syria'
            
        print(f"{l};{l}, {country}")
# Out:
# more than 1 matches... likely due to different granularity of entities with the same name (ie. Herat City in Herat Province) ['SY050100', 'SY05', 'SY0501']
# Hama;Hama, Syria
# more than 1 matches... likely due to different granularity of entities with the same name (ie. Herat City in Herat Province) ['SY0703', 'SY070300']
# Harim;Harim, Syria
# more than 1 matches... likely due to different granularity of entities with the same name (ie. Herat City in Herat Province) ['SY07', 'SY0700', 'SY070000']
# Idleb;Idleb, Syria
# more than 1 matches... likely due to different granularity of entities with the same name (ie. Herat City in Herat Province) ['SY020300', 'SY0203']
# Afrin;Afrin, Syria
# Aleppo;Aleppo, Syria
# Kahramanmara;Kahramanmara, Turkiye
# Malatya;Malatya, Turkiye
# Hatay;Hatay, Turkiye
# Adana;Adana, Turkiye
# Gaziantep;Gaziantep, Turkiye
# Sanliurfa;Sanliurfa, Turkiye
# more than 1 matches... likely due to different granularity of entities with the same name (ie. Herat City in Herat Province) ['TUR067008', 'TUR067']
# Zonguldak;Zonguldak, Turkiye
# Ordu;Ordu, Turkiye
# more than 1 matches... likely due to different granularity of entities with the same name (ie. Herat City in Herat Province) ['TUR002001', 'TUR002']
# Adiyaman;Adiyaman, Turkiye
# more than 1 matches... likely due to different granularity of entities with the same name (ie. Herat City in Herat Province) ['TUR057008', 'TUR057']
# Sinop;Sinop, Turkiye
# more than 1 matches... likely due to different granularity of entities with the same name (ie. Herat City in Herat Province) ['SY060000', 'SY06', 'SY0600']
# Lattakia;Lattakia, Syria
# more than 1 matches... likely due to different granularity of entities with the same name (ie. Herat City in Herat Province) ['TUR012002', 'TUR012']
# Bingl;Bingl, Turkiye
# Kayseri;Kayseri, Turkiye
# Mardin;Mardin, Turkiye
# more than 1 matches... likely due to different granularity of entities with the same name (ie. Herat City in Herat Province) ['TUR062', 'TUR062008']
# Tunceli;Tunceli, Turkiye
# more than 1 matches... likely due to different granularity of entities with the same name (ie. Herat City in Herat Province) ['TUR072', 'TUR072001']
# Batman;Batman, Turkiye
# Turkey;Turkey, Turkiye
# Samsun;Samsun, Turkiye
# more than 1 matches... likely due to different granularity of entities with the same name (ie. Herat City in Herat Province) ['TUR005001', 'TUR005']
# Amasya;Amasya, Turkiye
# Jandairis;Jandairis, Syria
# more than 1 matches... likely due to different granularity of entities with the same name (ie. Herat City in Herat Province) ['TUR037014', 'TUR037']
# Kastamonu;Kastamonu, Turkiye
# more than 1 matches... likely due to different granularity of entities with the same name (ie. Herat City in Herat Province) ['SY04', 'SY040100', 'SY0401']
# Homs;Homs, Syria
# more than 1 matches... likely due to different granularity of entities with the same name (ie. Herat City in Herat Province) ['SY10', 'SY100000', 'SY1000']
# Tartous;Tartous, Syria
# Mersin;Mersin, Turkiye
# Sakarya;Sakarya, Turkiye
# more than 1 matches... likely due to different granularity of entities with the same name (ie. Herat City in Herat Province) ['TUR014', 'TUR014001']
# Bolu;Bolu, Turkiye
# more than 1 matches... likely due to different granularity of entities with the same name (ie. Herat City in Herat Province) ['TUR074002', 'TUR074']
# Bartin;Bartin, Turkiye
# more than 1 matches... likely due to different granularity of entities with the same name (ie. Herat City in Herat Province) ['TUR078003', 'TUR078']
# Karabk;Karabk, Turkiye
# more than 1 matches... likely due to different granularity of entities with the same name (ie. Herat City in Herat Province) ['TUR028', 'TUR028009']
# Giresun;Giresun, Turkiye
# Naqaa;Naqaa, Turkiye
